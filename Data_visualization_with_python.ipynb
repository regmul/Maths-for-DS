# %% [markdown]
# <a href="https://colab.research.google.com/github/regmul/Maths-for-DS/blob/main/Data_visualization_with_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
mallc_df = pd.read_csv('Mall_Customers.csv')

# %%
mallc_df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
mallc_df.head(15)
# Out:
#     CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0            1    Male   19                  15                      39
# 1            2    Male   21                  15                      81
# 2            3  Female   20                  16                       6
# 3            4  Female   23                  16                      77
# 4            5  Female   31                  17                      40
# 5            6  Female   22                  17                      76
# 6            7  Female   35                  18                       6
# 7            8  Female   23                  18                      94
# 8            9    Male   64                  19                       3
# 9           10  Female   30                  19                      72
# 10          11    Male   67                  19                      14
# 11          12  Female   35                  19                      99
# ...

# %%
mallc_df.tail()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
mallc_df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
mallc_df['Age']
# Out:
# 0      19
# 1      21
# 2      20
# 3      23
# 4      31
#        ..
# 195    35
# 196    45
# 197    32
# 198    32
# 199    30
# Name: Age, Length: 200, dtype: int64

# %%
mallc_df[['Age','Annual Income (k$)', 'Spending Score (1-100)']]
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)
# 0     19                  15                      39
# 1     21                  15                      81
# 2     20                  16                       6
# 3     23                  16                      77
# 4     31                  17                      40
# ..   ...                 ...                     ...
# 195   35                 120                      79
# 196   45                 126                      28
# 197   32                 126                      74
# 198   32                 137                      18
# 199   30                 137                      83
#
# [200 rows x 3 columns]

# %%
mallc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
mallc_df.columns
# Out:
# Index(['CustomerID', 'Gender', 'Age', 'Annual Income (k$)',
#        'Spending Score (1-100)'],
#       dtype='object')

# %%
mallc_df.set_index(mallc_df.CustomerID)
# Out:
#             CustomerID  Gender  Age  Annual Income (k$)  \
# CustomerID
# 1                    1    Male   19                  15
# 2                    2    Male   21                  15
# 3                    3  Female   20                  16
# 4                    4  Female   23                  16
# 5                    5  Female   31                  17
# ...                ...     ...  ...                 ...
# 196                196  Female   35                 120
# 197                197  Female   45                 126
# 198                198    Male   32                 126
# 199                199    Male   32                 137
# 200                200    Male   30                 137
#
#             Spending Score (1-100)
# CustomerID
# 1                               39
# 2                               81
# 3                                6
# 4                               77
# 5                               40
# ...                            ...
# ...

# %%
mallc_df.index
# Out:
# RangeIndex(start=0, stop=200, step=1)

# %%
mallc_df.sample(30)
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 61           62    Male   19                  46                      55
# 134         135    Male   20                  73                       5
# 34           35  Female   49                  33                      14
# 70           71    Male   70                  49                      55
# 9            10  Female   30                  19                      72
# 83           84  Female   46                  54                      44
# 67           68  Female   68                  48                      48
# 92           93    Male   48                  60                      49
# 196         197  Female   45                 126                      28
# 136         137  Female   44                  73                       7
# 32           33    Male   53                  33                       4
# 121         122  Female   38                  67                      40
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
sns.scatterplot(data = mallc_df, x = 'Age', y = 'Spending Score (1-100)')
plt.title('Scatter Plot of Age vs Spending Score')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of Age vs Spending Score')

# %%
fig = px.scatter(mallc_df, x="Age", y="Spending Score (1-100)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
